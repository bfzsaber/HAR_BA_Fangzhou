# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch
import yaml
import os

import torch
from ptflops import get_model_complexity_info

# %%
torch.__version__
# Out:
# '1.13.1+cu117'

# %% [markdown]
# # Parameter settings

# %% [markdown]
# # Training parameters

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   
# TODO change the path as relative path
args.to_save_path     = r"../../Run_logs"            
args.freq_save_path   = r"../../Freq_data"
args.window_save_path = r"../../Sliding_window"
args.root_path        = r"../../datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 256                                                     
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 150

args.learning_rate           = 0.001  
args.learning_rate_patience  = 7
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 15

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 0
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

# %% [markdown]
# ## Data parameters

# %%
# oppo : 25/50  2
# dg   : 12/24  4
# dsads: 12/24  4
# pamap2: 10/20  5
# wisdm: 12/24  4
# skodar : 12/24 4

# %%
args.seed                             = 1


args.data_name                        =  "dsads"

args.wavelet_filtering                = False
args.wavelet_filtering_regularization = False
args.wavelet_filtering_finetuning     = False
args.wavelet_filtering_finetuning_percent = 0.5
args.wavelet_filtering_learnable      = False
args.wavelet_filtering_layernorm      = False

args.regulatization_tradeoff          = 0
args.number_wavelet_filtering         = 12


args.difference       = False 
args.filtering        =  False
args.magnitude        =  False
args.weighted_sampler = False




args.pos_select       = None
args.sensor_select    = None


args.representation_type = "time"
args.exp_mode            = "LOCV"
if args.data_name      ==  "skodar":
    args.exp_mode            = "SOCV"
config_file = open('../../configs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
window_seconds       = config["window_seconds"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
args.c_in            = config["num_channels"]


if args.difference:
    args.c_in = args.c_in*2

if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.f_in            =  args.number_wavelet_filtering*N_ds+1
else:
    args.f_in            =  1

# %% [markdown]
# ## Model parameters

# %%
# dsads 27838817.0 99367   26
# skodar  9907786.0   67092 24
# wisdm 733382.0 16
# dg  1041602.0 16
# oppo 7377290.0 28

# %%
# 如果我们设置为 


args.model_type              = "tinyhar"#"deepconvlstm"#"sahar" #"deepconvlstm"

args.cross_channel_interaction_type = "attn"
args.cross_channel_aggregation_type = "FC"
args.temporal_info_interaction_type = "conv"
args.temporal_info_aggregation_type = "tnaive"

exp = Exp(args)
# Out:
# Use GPU: cuda:0
# Build the TinyHAR model!
# Done!
# Parameter : 61895
# Set the seed as :  1

# %%
macs, params = get_model_complexity_info(exp.model, (1  ,args.input_length,args.c_in), as_strings=False,
                                       print_per_layer_stat=True, verbose=False)
print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# model_builder(
#   160, 0.259% Params, 708.86 KMac, 100.000% MACs,
#   (model): TinyHAR_Model(
#     160, 0.259% Params, 708.86 KMac, 100.000% MACs,
#     (quant_8): QuantIdentity(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#       (input_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (fused_activation_quant_proxy): FusedActivationQuantProxy(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): ParameterFromRuntimeStatsScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (stats): _Stats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_scaling): _RestrictValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (clamp_scaling): _ClampValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#       )
#     )
#     (quant_4): QuantIdentity(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#       (input_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (fused_activation_quant_proxy): FusedActivationQuantProxy(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): ParameterFromRuntimeStatsScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (stats): _Stats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_scaling): _RestrictValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (clamp_scaling): _ClampValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#       )
#     )
#     (layers_conv): ModuleList(
#       160, 0.259% Params, 704.7 KMac, 99.413% MACs,
#       (0): Sequential(
#         40, 0.065% Params, 326.7 KMac, 46.088% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 1, 20, kernel_size=(5, 1), stride=(1, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 108.9 KMac, 15.363% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 108.9 KMac, 15.363% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 108.9 KMac, 15.363% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 108.9 KMac, 15.363% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.065% Params, 217.8 KMac, 30.725% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): Sequential(
#         40, 0.065% Params, 159.3 KMac, 22.473% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 20, 20, kernel_size=(5, 1), stride=(2, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 53.1 KMac, 7.491% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 53.1 KMac, 7.491% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 53.1 KMac, 7.491% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 53.1 KMac, 7.491% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.065% Params, 106.2 KMac, 14.982% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (2): Sequential(
#         40, 0.065% Params, 148.5 KMac, 20.949% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 20, 20, kernel_size=(5, 1), stride=(1, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 49.5 KMac, 6.983% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 49.5 KMac, 6.983% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 49.5 KMac, 6.983% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 49.5 KMac, 6.983% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.065% Params, 99.0 KMac, 13.966% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (3): Sequential(
#         40, 0.065% Params, 70.2 KMac, 9.903% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 20, 20, kernel_size=(5, 1), stride=(2, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 23.4 KMac, 3.301% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 23.4 KMac, 3.301% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 23.4 KMac, 3.301% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 23.4 KMac, 3.301% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.065% Params, 46.8 KMac, 6.602% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (channel_interaction): SelfAttention_interaction(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#       (query): QuantLinear(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=20, out_features=20, bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (parameter_list_stats): _ParameterListStats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (first_tracked_param): _ViewParameterWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
# ...
#             (act_quant): ActQuantProxyFromInjector(
#               0, 0.000% Params, 1.04 KMac, 0.147% MACs,
#               (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (fused_activation_quant_proxy): FusedActivationQuantProxy(
#                 0, 0.000% Params, 1.04 KMac, 0.147% MACs,
#                 (activation_impl): ReLU(0, 0.000% Params, 1.04 KMac, 0.147% MACs, )
#                 (tensor_quant): RescalingIntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (int_quant): IntQuant(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (delay_wrapper): DelayWrapper(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                   )
#                   (scaling_impl): ParameterFromRuntimeStatsScaling(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (stats): _Stats(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                     (restrict_scaling): _RestrictValue(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                     (clamp_scaling): _ClampValue(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                     (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (zero_point_impl): ZeroZeroPoint(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (msb_clamp_bit_width_impl): BitWidthConst(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (dropout): QuantDropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#     (temporal_fusion): Temporal_Weighted_Aggregation(
#       0, 0.000% Params, 1.04 KMac, 0.147% MACs,
#       (fc_1): QuantLinear(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=40, out_features=40, bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (parameter_list_stats): _ParameterListStats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (first_tracked_param): _ViewParameterWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#       (weighs_activation): QuantReLU(
#         0, 0.000% Params, 1.04 KMac, 0.147% MACs,
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 1.04 KMac, 0.147% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             0, 0.000% Params, 1.04 KMac, 0.147% MACs,
#             (activation_impl): ReLU(0, 0.000% Params, 1.04 KMac, 0.147% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (clamp_scaling): _ClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#         )
#       )
#       (fc_2): QuantLinear(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=40, out_features=1, bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (parameter_list_stats): _ParameterListStats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (first_tracked_param): _ViewParameterWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#       (sm): Softmax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, dim=1)
#     )
#     (prediction): QuantLinear(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=40, out_features=19, bias=True
#       (input_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (tensor_quant): RescalingIntQuant(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (int_quant): IntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (delay_wrapper): DelayWrapper(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (parameter_list_stats): _ParameterListStats(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (first_tracked_param): _ViewParameterWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (stats): _Stats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#           (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (zero_point_impl): ZeroZeroPoint(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#     )
#   )
# )
# Computational complexity:       708860.0
# Number of parameters:           61895

# %%
exp.train()
# Out:
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 8 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [0.00273224 0.0027027  0.00257069 0.00268097 0.00263852 0.0026178
#  0.00260417 0.00262467 0.0025974  0.00265252 0.00265252 0.00269542
#  0.00265957 0.0025974  0.00262467 0.0026455  0.00268097 0.00268097
#  0.0026178 ]
# Train data number :  7182
# The number of classes is :  19
# The input_length  is :  125
# The channel_in is :  45
# Validation data number :  798
# Test data number :  1140
# ================ Build the model ================
# Build the TinyHAR model!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_4318/3332912701.py in <module>
# ----> 1 exp.train()
#
# ~/finn/notebooks/HAR/experiment.py in train(self)
#     328                         #        outputs = self.model(batch_x1)[0]
#     329                         #    else:
# --> 330                         outputs = self.model(batch_x1) #--
#     331
#     332                         #if self.args.mixup:
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/finn/notebooks/HAR/models/model_builder.py in forward(self, x)
#     168             if self.args.wavelet_filtering_regularization:
#     169                 x = x * self.gamma
# --> 170         y = self.model(x)
#     171         return y
#     172
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/finn/notebooks/HAR/models/TinyHAR.py in forward(self, x)
#     689
#     690             x = self.quant_4(x)
# --> 691             x = self.channel_fusion(x)
#     692             x = self.activation(x)
#     693         elif self.cross_channel_aggregation_type in ["SFCC","SFCF","SFCF2"]:
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/finn/notebooks/HAR/models/TinyHAR.py in forward(self, x)
#     235
#     236     def forward(self, x):
# --> 237         x = self.fc(x)
#     238         return(x)
#     239
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/brevitas/nn/quant_linear.py in forward(self, input)
#      62
#      63     def forward(self, input: Union[Tensor, QuantTensor]) -> Union[Tensor, QuantTensor]:
# ---> 64         return self.forward_impl(input)
#      65
#      66     def inner_forward_impl(self, x: Tensor, quant_weight: Tensor, quant_bias: Optional[Tensor]):
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/brevitas/nn/quant_layer.py in forward_impl(self, inp)
#     332                 output_bit_width = output_bit_width + 1
#     333         else:
# --> 334             output_tensor = self.inner_forward_impl(quant_input.value, quant_weight.value, None)
#     335
#     336         if self.return_quant_tensor and not self.is_output_quant_enabled:
#
# ~/anaconda3/envs/FPGA/lib/python3.7/site-packages/brevitas/nn/quant_linear.py in inner_forward_impl(self, x, quant_weight, quant_bias)
#      65
#      66     def inner_forward_impl(self, x: Tensor, quant_weight: Tensor, quant_bias: Optional[Tensor]):
# ---> 67         output_tensor = linear(x, quant_weight, quant_bias)
#      68         return output_tensor
#      69
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (26x230400 and 900x40)

# %% [markdown]
# # Brevitas Export

# %%
from models.TinyHAR import TinyHAR_Model
from brevitas.export import export_onnx_qcdq

# %% [markdown]
# Train data number :  7182
# The number of classes is :  19
# The input_length  is :  125
# The channel_in is :  45
# Validation data number :  798
# Test data number :  1140

# %%
num_classes = 19
num_channels =45
windowsize = 125
input_shape =(1, 1, windowsize, num_channels)
print(input_shape)
config_file = open('../../configs/model.yaml', mode='r')
config = yaml.load(config_file, Loader=yaml.FullLoader)["tinyhar"]

# %%
model = TinyHAR_Model(input_shape = input_shape,
                      number_class = num_classes,
                      filter_num = 20,
                      cross_channel_interaction_type = "attn",
                      cross_channel_aggregation_type = "FC",
                      temporal_info_interaction_type = "conv",
                      temporal_info_aggregation_type = "tnaive")

# %%
loadPath = "/home/bian/finn/notebooks/HAR/Run_logs/logs/DSADS1/cv_5/final_best_vali.pth"

model.load_state_dict(torch.load(loadPath),strict=False)
model.eval()

# %%
import torch
import brevitas.onnx as bo
from brevitas.quant_tensor import QuantTensor

ready_model_filename = "dsads_attn_conv_4.onnx"

# Export to ONNX
#Move to CPU before export
model.cpu()


inp = torch.randn(1,1,windowsize,num_channels)
bo.export_finn_onnx(model, inp, ready_model_filename)
"""
torch.onnx.export(model, 
                  data_usage, 
                  ready_model_filename,   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file         # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'] # the model's output names
                  )
"""
print("Model saved to %s" % ready_model_filename)

# %% [markdown]
# # Measurement

# %%
from LatencyMeasurer import LatencyMeasurer

# %%
model = model.cpu()
measurer = LatencyMeasurer(model)

cpu_latency = measurer.measure_latency_CPU(input_shape)
cpu_finn_latency = measurer.measure_CPU_latency_finn(model.forward_truncated, input_shape)
print(f"cpu latency for quantized TinyHAR: {cpu_latency}s,\nfinn part latency: {cpu_finn_latency}s")

# %%
model = model.cuda()
measurer = LatencyMeasurer(model)
gpu_latency = measurer.measure_GPU_latency(input_shape)
gpu_finn_latency = measurer.measure_GPU_finn_latency(model.forward_truncated, input_shape)
print(f"gpu latency for quantized TinyHAR: {gpu_latency}s,\nfinn part latency: {gpu_finn_latency}s")

# %%
import PowerMeasurer
model = model.cuda()
gpu_power = PowerMeasurer.measure_gpu_power(model, input_shape)
gpu_power_finn = PowerMeasurer.measure_gpu_finn_power(model, model.forward_truncated,input_shape)
print(f"gpu power consumption for quantized TinyHAR: {gpu_power}W,\nfinn part latency: {gpu_power_finn}w")

# %% [markdown]
# # 实验

# %%
# 如果我们设置为 


args.model_type              = "tinyhar"#"deepconvlstm"#"sahar" #"deepconvlstm"

args.cross_channel_interaction_type = "attn"
args.cross_channel_aggregation_type = "FC"
args.temporal_info_interaction_type = "lstm"
args.temporal_info_aggregation_type = "tnaive"

exp = Exp(args)

# %%
exp.model

# %%
exp.train()

# %%
dataset = data_dict[args.data_name](args)

# %%
import numpy as np

# %%
start_index = dataset.train_slidingwindows[0][1]
end_index   = dataset.train_slidingwindows[0][2]
sample_x_1    = dataset.data_x.iloc[start_index:end_index, 1:-1].values

start_index = dataset.train_slidingwindows[100][1]
end_index   = dataset.train_slidingwindows[100][2]
sample_x_2    = dataset.data_x.iloc[start_index:end_index, 1:-1].values

temp_1 = np.expand_dims(sample_x_1,0)
temp_2 = np.expand_dims(sample_x_2,0)
combined_x = np.concatenate([temp_1,temp_2],axis=0)
combined_x = np.expand_dims(combined_x,1)
combined_x = torch.tensor(combined_x).double().to(exp.device)
print(combined_x.shape)

# %%
out = exp.model(combined_x)
out = out.cpu().detach().numpy()

# %%
out.shape

# %%
weight = exp.model.wave_conv.wavelet_conv.weight.cpu().detach().numpy()

# %%
for n,p in exp.model.named_parameters():
    print(n)

# %%
import matplotlib.pyplot as plt
index1 = 0
index2 = 0

plt.figure()
plt.plot(out[0,0,:,index2])
plt.plot(out[0,1,:,index2])
plt.plot(out[0,2,:,index2])
plt.plot(out[0,3,:,index2])

# %%
# 如果我们设置为 
# args.wavelet_filtering_learnable      = True
# exp = Exp(args)
