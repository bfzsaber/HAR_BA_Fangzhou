# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch
import yaml
import os

import torch
from ptflops import get_model_complexity_info

# %%
torch.__version__
# Out:
# '1.13.1+cu117'

# %% [markdown]
# # Parameter settings

# %% [markdown]
# # Training parameters

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   
# TODO change the path as relative path
args.to_save_path     = r"../../Run_logs"            
args.freq_save_path   = r"../../Freq_data"
args.window_save_path = r"../../Sliding_window"
args.root_path        = r"../../datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 256                                                     
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 150

args.learning_rate           = 0.001  
args.learning_rate_patience  = 7
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 15

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 0
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

# %% [markdown]
# ## Data parameters

# %%
# oppo : 25/50  2
# dg   : 12/24  4
# dsads: 12/24  4
# pamap2: 10/20  5
# wisdm: 12/24  4
# skodar : 12/24 4

# %%
args.seed                             = 1


args.data_name                        =  "pamap2"

args.wavelet_filtering                = False
args.wavelet_filtering_regularization = False
args.wavelet_filtering_finetuning     = False
args.wavelet_filtering_finetuning_percent = 0.5
args.wavelet_filtering_learnable      = False
args.wavelet_filtering_layernorm      = False

args.regulatization_tradeoff          = 0
args.number_wavelet_filtering         = 12


args.difference       = False 
args.filtering        =  False
args.magnitude        =  False
args.weighted_sampler = False




args.pos_select       = None
args.sensor_select    = None


args.representation_type = "time"
args.exp_mode            = "LOCV"
if args.data_name      ==  "skodar":
    args.exp_mode            = "SOCV"
config_file = open('../../configs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
window_seconds       = config["window_seconds"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
args.c_in            = config["num_channels"]


if args.difference:
    args.c_in = args.c_in*2

if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.f_in            =  args.number_wavelet_filtering*N_ds+1
else:
    args.f_in            =  1

# %% [markdown]
# ## Model parameters

# %%
# dsads 27838817.0 99367   26
# skodar  9907786.0   67092 24
# wisdm 733382.0 16
# dg  1041602.0 16
# oppo 7377290.0 28

# %%
# 如果我们设置为 


args.model_type              = "tinyhar"#"deepconvlstm"#"sahar" #"deepconvlstm"

args.cross_channel_interaction_type = "attn"
args.cross_channel_aggregation_type = "FC"
args.temporal_info_interaction_type = "conv"
args.temporal_info_aggregation_type = "tnaive"

exp = Exp(args)
# Out:
# Use GPU: cuda:0
# Build the TinyHAR model!
# Done!
# Parameter : 40008
# Set the seed as :  1

# %%
macs, params = get_model_complexity_info(exp.model, (1  ,args.input_length,args.c_in), as_strings=False,
                                       print_per_layer_stat=True, verbose=False)
print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# model_builder(
#   160, 0.400% Params, 390.24 KMac, 100.000% MACs,
#   (model): TinyHAR_Model(
#     160, 0.400% Params, 390.24 KMac, 100.000% MACs,
#     (quant_8): QuantIdentity(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#       (input_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (fused_activation_quant_proxy): FusedActivationQuantProxy(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): ParameterFromRuntimeStatsScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (stats): _Stats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_scaling): _RestrictValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (clamp_scaling): _ClampValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#       )
#     )
#     (quant_4): QuantIdentity(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#       (input_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (act_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (fused_activation_quant_proxy): FusedActivationQuantProxy(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): ParameterFromRuntimeStatsScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (stats): _Stats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_scaling): _RestrictValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (clamp_scaling): _ClampValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#       )
#     )
#     (layers_conv): ModuleList(
#       160, 0.400% Params, 384.48 KMac, 98.524% MACs,
#       (0): Sequential(
#         40, 0.100% Params, 177.12 KMac, 45.387% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 1, 20, kernel_size=(5, 1), stride=(1, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 59.04 KMac, 15.129% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 59.04 KMac, 15.129% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 59.04 KMac, 15.129% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 59.04 KMac, 15.129% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.100% Params, 118.08 KMac, 30.258% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): Sequential(
#         40, 0.100% Params, 86.4 KMac, 22.140% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 20, 20, kernel_size=(5, 1), stride=(2, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 28.8 KMac, 7.380% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 28.8 KMac, 7.380% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 28.8 KMac, 7.380% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 28.8 KMac, 7.380% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.100% Params, 57.6 KMac, 14.760% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (2): Sequential(
#         40, 0.100% Params, 82.08 KMac, 21.033% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 20, 20, kernel_size=(5, 1), stride=(1, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 27.36 KMac, 7.011% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 27.36 KMac, 7.011% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 27.36 KMac, 7.011% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 27.36 KMac, 7.011% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.100% Params, 54.72 KMac, 14.022% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#       (3): Sequential(
#         40, 0.100% Params, 38.88 KMac, 9.963% MACs,
#         (0): QuantConv2d(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs, 20, 20, kernel_size=(5, 1), stride=(2, 1), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (parameter_list_stats): _ParameterListStats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (first_tracked_param): _ViewParameterWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): QuantReLU(
#           0, 0.000% Params, 12.96 KMac, 3.321% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 12.96 KMac, 3.321% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 12.96 KMac, 3.321% MACs,
#               (activation_impl): ReLU(0, 0.000% Params, 12.96 KMac, 3.321% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#         (2): BatchNorm2d(40, 0.100% Params, 25.92 KMac, 6.642% MACs, 20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): QuantIdentity(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (input_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (activation_impl): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_quant): RescalingIntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (int_quant): IntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (delay_wrapper): DelayWrapper(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (stats): _Stats(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (clamp_scaling): _ClampValue(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (zero_point_impl): ZeroZeroPoint(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (channel_interaction): SelfAttention_interaction(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#       (query): QuantLinear(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=20, out_features=20, bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (parameter_list_stats): _ParameterListStats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (first_tracked_param): _ViewParameterWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
# ...
#             (act_quant): ActQuantProxyFromInjector(
#               0, 0.000% Params, 1.44 KMac, 0.369% MACs,
#               (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (fused_activation_quant_proxy): FusedActivationQuantProxy(
#                 0, 0.000% Params, 1.44 KMac, 0.369% MACs,
#                 (activation_impl): ReLU(0, 0.000% Params, 1.44 KMac, 0.369% MACs, )
#                 (tensor_quant): RescalingIntQuant(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (int_quant): IntQuant(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (delay_wrapper): DelayWrapper(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                   )
#                   (scaling_impl): ParameterFromRuntimeStatsScaling(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (stats): _Stats(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                     (restrict_scaling): _RestrictValue(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                     (clamp_scaling): _ClampValue(
#                       0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                       (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     )
#                     (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                     (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (zero_point_impl): ZeroZeroPoint(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                   (msb_clamp_bit_width_impl): BitWidthConst(
#                     0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                     (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     (dropout): QuantDropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#     (temporal_fusion): Temporal_Weighted_Aggregation(
#       0, 0.000% Params, 1.44 KMac, 0.369% MACs,
#       (fc_1): QuantLinear(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=40, out_features=40, bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (parameter_list_stats): _ParameterListStats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (first_tracked_param): _ViewParameterWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#       (weighs_activation): QuantReLU(
#         0, 0.000% Params, 1.44 KMac, 0.369% MACs,
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 1.44 KMac, 0.369% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             0, 0.000% Params, 1.44 KMac, 0.369% MACs,
#             (activation_impl): ReLU(0, 0.000% Params, 1.44 KMac, 0.369% MACs, )
#             (tensor_quant): RescalingIntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (int_quant): IntQuant(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (tensor_clamp_impl): TensorClamp(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (delay_wrapper): DelayWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_input_view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsPercentile(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (clamp_scaling): _ClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_inplace_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_preprocess): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (zero_point_impl): ZeroZeroPoint(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#           )
#         )
#       )
#       (fc_2): QuantLinear(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=40, out_features=1, bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (tensor_quant): RescalingIntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (int_quant): IntQuant(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (delay_wrapper): DelayWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (parameter_list_stats): _ParameterListStats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (first_tracked_param): _ViewParameterWrapper(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (stats): _Stats(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                   (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                   (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 )
#                 (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (zero_point_impl): ZeroZeroPoint(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#       (sm): Softmax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, dim=1)
#     )
#     (prediction): QuantLinear(
#       0, 0.000% Params, 0.0 Mac, 0.000% MACs, in_features=40, out_features=12, bias=True
#       (input_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (tensor_quant): RescalingIntQuant(
#           0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#           (int_quant): IntQuant(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (float_to_int_impl): RoundSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (tensor_clamp_impl): TensorClampSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (delay_wrapper): DelayWrapper(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (delay_impl): _NoDelay(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (parameter_list_stats): _ParameterListStats(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (first_tracked_param): _ViewParameterWrapper(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (view_shape_impl): OverTensorView(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (stats): _Stats(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (stats_impl): AbsMax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#               (affine_rescaling): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#                 (clamp_min_ste): ScalarClampMinSte(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#                 (restrict_value_impl): FloatRestrictValue(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#               (restrict_scaling_pre): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             )
#           )
#           (int_scaling_impl): IntScaling(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (zero_point_impl): ZeroZeroPoint(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (zero_point): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#             (bit_width): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         0, 0.000% Params, 0.0 Mac, 0.000% MACs,
#         (_zero_hw_sentinel): StatelessBuffer(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#     )
#   )
# )
# Computational complexity:       390240.0
# Number of parameters:           40008

# %% [markdown]
# exp.

# %%
exp.train()
# Out:
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 9 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [0.00171233 0.00170358 0.0016835  0.001287   0.00362319 0.00200401
#  0.00166113 0.0028169  0.00308642 0.00182815 0.00129366 0.00775194]
# Train data number :  6047
# The number of classes is :  12
# The input_length  is :  168
# The channel_in is :  18
# Validation data number :  672
# Test data number :  5207
# ================ Build the model ================
# Build the TinyHAR model!
# Epoch: 1 cost time: 82.25668406486511
# VALI: Epoch: 1, Steps: 24 | Train Loss: 2.3409740  Vali Loss: 2.3567735 Vali Accuracy: 0.1755952  Vali weighted F1: 0.0764208  Vali macro F1 0.0551867
# Validation loss decreased (inf --> 2.356773).  Saving model ...
# Epoch: 2 cost time: 83.17859697341919
# VALI: Epoch: 2, Steps: 24 | Train Loss: 1.9017939  Vali Loss: 1.6077754 Vali Accuracy: 0.3958333  Vali weighted F1: 0.2784255  Vali macro F1 0.2631907
# new best score!!!!
# Validation loss decreased (2.356773 --> 1.607775).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 82.99688458442688
# VALI: Epoch: 3, Steps: 24 | Train Loss: 1.4025165  Vali Loss: 1.2107074 Vali Accuracy: 0.5178571  Vali weighted F1: 0.4365678  Vali macro F1 0.4780644
# new best score!!!!
# Validation loss decreased (1.607775 --> 1.210707).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 82.50700092315674
# VALI: Epoch: 4, Steps: 24 | Train Loss: 1.1011829  Vali Loss: 0.9406815 Vali Accuracy: 0.7232143  Vali weighted F1: 0.7197305  Vali macro F1 0.7256174
# new best score!!!!
# Validation loss decreased (1.210707 --> 0.940681).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 81.89003014564514
# VALI: Epoch: 5, Steps: 24 | Train Loss: 0.7992040  Vali Loss: 0.9433787 Vali Accuracy: 0.7068452  Vali weighted F1: 0.7040436  Vali macro F1 0.7273858
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 7
# Epoch: 6 cost time: 82.25058317184448
# VALI: Epoch: 6, Steps: 24 | Train Loss: 0
# EarlyStopping counter: 4 out of 15
# Learning rate adjusting counter: 4 out of 7
# Epoch: 57 cost time: 39.833322048187256
# VALI: Epoch: 57, Steps: 24 | Train Loss: 0.1171374  Vali Loss: 0.3151913 Vali Accuracy: 0.9285714  Vali weighted F1: 0.9291503  Vali macro F1 0.9285357
# EarlyStopping counter: 5 out of 15
# Learning rate adjusting counter: 5 out of 7
# Epoch: 58 cost time: 39.793198585510254
# VALI: Epoch: 58, Steps: 24 | Train Loss: 0.1205005  Vali Loss: 0.3063336 Vali Accuracy: 0.9315476  Vali weighted F1: 0.9322178  Vali macro F1 0.9300062
# EarlyStopping counter: 6 out of 15
# Learning rate adjusting counter: 6 out of 7
# Epoch: 59 cost time: 39.766003370285034
# VALI: Epoch: 59, Steps: 24 | Train Loss: 0.1266735  Vali Loss: 0.3313478 Vali Accuracy: 0.9285714  Vali weighted F1: 0.9294915  Vali macro F1 0.9289214
# EarlyStopping counter: 7 out of 15
# Learning rate adjusting counter: 7 out of 7
# Updating learning rate to 1e-05
# Epoch: 60 cost time: 39.771230936050415
# VALI: Epoch: 60, Steps: 24 | Train Loss: 0.1197564  Vali Loss: 0.3375222 Vali Accuracy: 0.9330357  Vali weighted F1: 0.9336349  Vali macro F1 0.9329604
# EarlyStopping counter: 8 out of 15
# Learning rate adjusting counter: 1 out of 7
# Epoch: 61 cost time: 39.79540705680847
# VALI: Epoch: 61, Steps: 24 | Train Loss: 0.1214239  Vali Loss: 0.3180877 Vali Accuracy: 0.9360119  Vali weighted F1: 0.9364571  Vali macro F1 0.9349230
# EarlyStopping counter: 9 out of 15
# Learning rate adjusting counter: 2 out of 7
# Epoch: 62 cost time: 39.736711263656616
# VALI: Epoch: 62, Steps: 24 | Train Loss: 0.1225993  Vali Loss: 0.3218380 Vali Accuracy: 0.9330357  Vali weighted F1: 0.9337851  Vali macro F1 0.9339278
# EarlyStopping counter: 10 out of 15
# Learning rate adjusting counter: 3 out of 7
# Epoch: 63 cost time: 33.03620672225952
# VALI: Epoch: 63, Steps: 24 | Train Loss: 0.1198053  Vali Loss: 0.3026024 Vali Accuracy: 0.9330357  Vali weighted F1: 0.9334786  Vali macro F1 0.9328810
# EarlyStopping counter: 11 out of 15
# Learning rate adjusting counter: 4 out of 7
# Epoch: 64 cost time: 47.99108600616455
# VALI: Epoch: 64, Steps: 24 | Train Loss: 0.1210022  Vali Loss: 0.3221400 Vali Accuracy: 0.9375000  Vali weighted F1: 0.9380652  Vali macro F1 0.9340096
# EarlyStopping counter: 12 out of 15
# Learning rate adjusting counter: 5 out of 7
# Epoch: 65 cost time: 45.82995414733887
# VALI: Epoch: 65, Steps: 24 | Train Loss: 0.1194062  Vali Loss: 0.3009858 Vali Accuracy: 0.9330357  Vali weighted F1: 0.9335567  Vali macro F1 0.9313753
# EarlyStopping counter: 13 out of 15
# Learning rate adjusting counter: 6 out of 7
# Epoch: 66 cost time: 46.92415714263916
# VALI: Epoch: 66, Steps: 24 | Train Loss: 0.1184978  Vali Loss: 0.3041138 Vali Accuracy: 0.9330357  Vali weighted F1: 0.9335855  Vali macro F1 0.9310829
# EarlyStopping counter: 14 out of 15
# Learning rate adjusting counter: 7 out of 7
# Updating learning rate to 1.0000000000000002e-06
# Epoch: 67 cost time: 47.92988395690918
# VALI: Epoch: 67, Steps: 24 | Train Loss: 0.1212590  Vali Loss: 0.3023626 Vali Accuracy: 0.9375000  Vali weighted F1: 0.9384865  Vali macro F1 0.9390336
# EarlyStopping counter: 15 out of 15
# Early stopping
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_14947/3332912701.py in <module>
# ----> 1 exp.train()
#
# ~/finn/notebooks/HAR/experiment.py in train(self)
#     376
#     377                 # rename the best_vali to final_best_vali
# --> 378                 os.rename(cv_path+'/'+'best_vali.pth', cv_path+'/'+'final_best_vali.pth')
#     379
#     380                 print("Loading the best validation model!")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Run_logs/logs/tinyhar_data_pamap2_seed_1_windowsize_168_cvfilter_20_CI_attn_CA_FC_TI_conv_TA_tnaive/cv_0/best_vali.pth' -> '../../Run_logs/logs/tinyhar_data_pamap2_seed_1_windowsize_168_cvfilter_20_CI_attn_CA_FC_TI_conv_TA_tnaive/cv_0/final_best_vali.pth'

# %% [markdown]
#  if self.args.model_type == "mcnn":
#             config_file = open('../../configs/model.yaml', mode='r')
#             config = yaml.load(config_file, Loader=yaml.FullLoader)["mcnn"]
#             setting = "mcnn_data_{}_seed_{}_windowsize_{}_waveFilter_{}_Fscaling_{}_cvfilter_{}_Regu_{}_wavelearnble_{}".format(self.args.data_name,
#                                                                                                                                               self.args.seed,
#                                                                                                                                               self.args.windowsize,
#                                                                                                                                               self.args.wavelet_filtering,
#                                                                                                                                               self.args.filter_scaling_factor,
#                                                                                                                                               config["nb_filters"],
#                                                                                                                                               self.args.wavelet_filtering_regularization,
#                                                                                                                                               self.args.wavelet_filtering_learnable )
#             return setting

# %% [markdown]
# pamap2:
#   filename: "PAMAP2_Dataset/Protocol"
#   sampling_freq: 33
#   num_classes: 12
#   num_channels: 18
#   window_seconds: 5.12
#
# self.model  = MCNN((1,f_in, self.args.input_length, self.args.c_in ),
#                                 self.args.num_classes,
#                                 self.args.filter_scaling_factor,
#                                 config)
# (1,1,169,18) 12, 1
# f_in = 1
# args.windowsize      =   int(window_seconds * args.sampling_freq)
#                      = 169
# args.filter_scaling_factor =1
#
# args.root_path       = os.path.join(args.root_path,config["filename"])
# args.sampling_freq   = config["sampling_freq"]
# args.num_classes     =  config["num_classes"]
# window_seconds       = config["window_seconds"]
# args.windowsize      =   int(window_seconds * args.sampling_freq)
# args.input_length    =  args.windowsize
# # input information
# args.c_in            = config["num_channels"]

# %%
from models.TinyHAR import TinyHAR_Model
from brevitas.export import export_onnx_qcdq

# %%
num_classes = 12
num_channels =18
windowsize = 168
input_shape =(1, 1, windowsize, num_channels)
print(input_shape)
config_file = open('../../configs/model.yaml', mode='r')
config = yaml.load(config_file, Loader=yaml.FullLoader)["tinyhar"]
# Out:
# (1, 1, 168, 18)

# %%
model = TinyHAR_Model(input_shape = input_shape,
                      number_class = num_classes,
                      filter_num = 20,
                      cross_channel_interaction_type = "attn",
                      cross_channel_aggregation_type = "FC",
                      temporal_info_interaction_type = "conv",
                      temporal_info_aggregation_type = "tnaive")

# %%
loadPath = "/home/bian/finn/notebooks/HAR/Run_logs/logs/tinyhar_data_pamap2_seed_1_windowsize_168_cvfilter_20_CI_attn_CA_FC_TI_conv_TA_tnaive/cv_0/final_best_vali.pth"

model.load_state_dict(torch.load(loadPath),strict=False)
model.eval()
# Out:
# TinyHAR_Model(
#   (quant_8): QuantIdentity(
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (act_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (fused_activation_quant_proxy): FusedActivationQuantProxy(
#         (activation_impl): Identity()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClamp()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): ParameterFromRuntimeStatsScaling(
#             (stats_input_view_shape_impl): OverTensorView()
#             (stats): _Stats(
#               (stats_impl): AbsPercentile()
#             )
#             (restrict_scaling): _RestrictValue(
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (clamp_scaling): _ClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#             )
#             (restrict_inplace_preprocess): Identity()
#             (restrict_preprocess): Identity()
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#     )
#   )
#   (quant_4): QuantIdentity(
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (act_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (fused_activation_quant_proxy): FusedActivationQuantProxy(
#         (activation_impl): Identity()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClamp()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): ParameterFromRuntimeStatsScaling(
#             (stats_input_view_shape_impl): OverTensorView()
#             (stats): _Stats(
#               (stats_impl): AbsPercentile()
#             )
#             (restrict_scaling): _RestrictValue(
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (clamp_scaling): _ClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#             )
#             (restrict_inplace_preprocess): Identity()
#             (restrict_preprocess): Identity()
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#     )
#   )
#   (layers_conv): ModuleList(
#     (0): Sequential(
#       (0): QuantConv2d(
#         1, 20, kernel_size=(5, 1), stride=(1, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (1): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): QuantIdentity(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): Sequential(
#       (0): QuantConv2d(
#         20, 20, kernel_size=(5, 1), stride=(2, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (1): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): QuantIdentity(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): QuantConv2d(
#         20, 20, kernel_size=(5, 1), stride=(1, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (1): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): QuantIdentity(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): QuantConv2d(
#         20, 20, kernel_size=(5, 1), stride=(2, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (1): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): QuantIdentity(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (channel_interaction): SelfAttention_interaction(
#     (query): QuantLinear(
#       in_features=20, out_features=20, bias=False
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClampSte()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             (parameter_list_stats): _ParameterListStats(
#               (first_tracked_param): _ViewParameterWrapper(
#                 (view_shape_impl): OverTensorView()
#               )
#               (stats): _Stats(
#                 (stats_impl): AbsMax()
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               (affine_rescaling): Identity()
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (restrict_scaling_pre): Identity()
#             )
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#     )
#     (key): QuantLinear(
#       in_features=20, out_features=20, bias=False
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClampSte()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             (parameter_list_stats): _ParameterListStats(
#               (first_tracked_param): _ViewParameterWrapper(
#                 (view_shape_impl): OverTensorView()
#               )
#               (stats): _Stats(
#                 (stats_impl): AbsMax()
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               (affine_rescaling): Identity()
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (restrict_scaling_pre): Identity()
#             )
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#     )
#     (value): QuantLinear(
#       in_features=20, out_features=20, bias=False
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClampSte()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             (parameter_list_stats): _ParameterListStats(
#               (first_tracked_param): _ViewParameterWrapper(
#                 (view_shape_impl): OverTensorView()
#               )
#               (stats): _Stats(
#                 (stats_impl): AbsMax()
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               (affine_rescaling): Identity()
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (restrict_scaling_pre): Identity()
#             )
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#     )
#   )
#   (channel_fusion): FC(
#     (fc): QuantLinear(
#       in_features=360, out_features=40, bias=False
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClampSte()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             (parameter_list_stats): _ParameterListStats(
#               (first_tracked_param): _ViewParameterWrapper(
#                 (view_shape_impl): OverTensorView()
#               )
#               (stats): _Stats(
#                 (stats_impl): AbsMax()
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               (affine_rescaling): Identity()
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (restrict_scaling_pre): Identity()
#             )
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#     )
#   )
#   (activation): QuantReLU(
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (act_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (fused_activation_quant_proxy): FusedActivationQuantProxy(
#         (activation_impl): ReLU()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClamp()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): ParameterFromRuntimeStatsScaling(
#             (stats_input_view_shape_impl): OverTensorView()
#             (stats): _Stats(
#               (stats_impl): AbsPercentile()
#             )
#             (restrict_scaling): _RestrictValue(
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (clamp_scaling): _ClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#             )
#             (restrict_inplace_preprocess): Identity()
#             (restrict_preprocess): Identity()
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#     )
#   )
#   (temporal_interaction): temporal_conv_1d(
#     (layers_conv): ModuleList(
#       (0): Sequential(
#         (0): QuantConv1d(
#           40, 40, kernel_size=(5,), stride=(1,), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClampSte()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 (parameter_list_stats): _ParameterListStats(
#                   (first_tracked_param): _ViewParameterWrapper(
#                     (view_shape_impl): OverTensorView()
#                   )
#                   (stats): _Stats(
#                     (stats_impl): AbsMax()
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   (affine_rescaling): Identity()
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     (clamp_min_ste): ScalarClampMinSte()
#                     (restrict_value_impl): FloatRestrictValue()
#                   )
#                   (restrict_scaling_pre): Identity()
#                 )
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#         )
#         (1): QuantReLU(
#           (input_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               (activation_impl): ReLU()
#               (tensor_quant): RescalingIntQuant(
#                 (int_quant): IntQuant(
#                   (float_to_int_impl): RoundSte()
#                   (tensor_clamp_impl): TensorClamp()
#                   (delay_wrapper): DelayWrapper(
#                     (delay_impl): _NoDelay()
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   (stats_input_view_shape_impl): OverTensorView()
#                   (stats): _Stats(
#                     (stats_impl): AbsPercentile()
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     (restrict_value_impl): FloatRestrictValue()
#                   )
#                   (clamp_scaling): _ClampValue(
#                     (clamp_min_ste): ScalarClampMinSte()
#                   )
#                   (restrict_inplace_preprocess): Identity()
#                   (restrict_preprocess): Identity()
#                 )
#                 (int_scaling_impl): IntScaling()
#                 (zero_point_impl): ZeroZeroPoint(
#                   (zero_point): StatelessBuffer()
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   (bit_width): StatelessBuffer()
#                 )
#               )
#             )
#           )
#         )
#       )
#       (1): Sequential(
#         (0): QuantConv1d(
#           40, 40, kernel_size=(5,), stride=(1,), bias=False
#           (input_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#           (output_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#           (weight_quant): WeightQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClampSte()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#               )
#               (scaling_impl): StatsFromParameterScaling(
#                 (parameter_list_stats): _ParameterListStats(
#                   (first_tracked_param): _ViewParameterWrapper(
#                     (view_shape_impl): OverTensorView()
#                   )
#                   (stats): _Stats(
#                     (stats_impl): AbsMax()
#                   )
#                 )
#                 (stats_scaling_impl): _StatsScaling(
#                   (affine_rescaling): Identity()
#                   (restrict_clamp_scaling): _RestrictClampValue(
#                     (clamp_min_ste): ScalarClampMinSte()
#                     (restrict_value_impl): FloatRestrictValue()
#                   )
#                   (restrict_scaling_pre): Identity()
#                 )
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#           (bias_quant): BiasQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#         )
#         (1): QuantReLU(
#           (input_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#           )
#           (act_quant): ActQuantProxyFromInjector(
#             (_zero_hw_sentinel): StatelessBuffer()
#             (fused_activation_quant_proxy): FusedActivationQuantProxy(
#               (activation_impl): ReLU()
#               (tensor_quant): RescalingIntQuant(
#                 (int_quant): IntQuant(
#                   (float_to_int_impl): RoundSte()
#                   (tensor_clamp_impl): TensorClamp()
#                   (delay_wrapper): DelayWrapper(
#                     (delay_impl): _NoDelay()
#                   )
#                 )
#                 (scaling_impl): ParameterFromRuntimeStatsScaling(
#                   (stats_input_view_shape_impl): OverTensorView()
#                   (stats): _Stats(
#                     (stats_impl): AbsPercentile()
#                   )
#                   (restrict_scaling): _RestrictValue(
#                     (restrict_value_impl): FloatRestrictValue()
#                   )
#                   (clamp_scaling): _ClampValue(
#                     (clamp_min_ste): ScalarClampMinSte()
#                   )
#                   (restrict_inplace_preprocess): Identity()
#                   (restrict_preprocess): Identity()
#                 )
#                 (int_scaling_impl): IntScaling()
#                 (zero_point_impl): ZeroZeroPoint(
#                   (zero_point): StatelessBuffer()
#                 )
#                 (msb_clamp_bit_width_impl): BitWidthConst(
#                   (bit_width): StatelessBuffer()
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (dropout): QuantDropout(p=0.1, inplace=False)
#   (temporal_fusion): Temporal_Weighted_Aggregation(
#     (fc_1): QuantLinear(
#       in_features=40, out_features=40, bias=False
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClampSte()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             (parameter_list_stats): _ParameterListStats(
#               (first_tracked_param): _ViewParameterWrapper(
#                 (view_shape_impl): OverTensorView()
#               )
#               (stats): _Stats(
#                 (stats_impl): AbsMax()
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               (affine_rescaling): Identity()
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (restrict_scaling_pre): Identity()
#             )
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#     )
#     (weighs_activation): QuantReLU(
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (act_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (fused_activation_quant_proxy): FusedActivationQuantProxy(
#           (activation_impl): ReLU()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClamp()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#             )
#             (scaling_impl): ParameterFromRuntimeStatsScaling(
#               (stats_input_view_shape_impl): OverTensorView()
#               (stats): _Stats(
#                 (stats_impl): AbsPercentile()
#               )
#               (restrict_scaling): _RestrictValue(
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (clamp_scaling): _ClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#               )
#               (restrict_inplace_preprocess): Identity()
#               (restrict_preprocess): Identity()
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#       )
#     )
#     (fc_2): QuantLinear(
#       in_features=40, out_features=1, bias=False
#       (input_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (output_quant): ActQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#       (weight_quant): WeightQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClampSte()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#           )
#           (scaling_impl): StatsFromParameterScaling(
#             (parameter_list_stats): _ParameterListStats(
#               (first_tracked_param): _ViewParameterWrapper(
#                 (view_shape_impl): OverTensorView()
#               )
#               (stats): _Stats(
#                 (stats_impl): AbsMax()
#               )
#             )
#             (stats_scaling_impl): _StatsScaling(
#               (affine_rescaling): Identity()
#               (restrict_clamp_scaling): _RestrictClampValue(
#                 (clamp_min_ste): ScalarClampMinSte()
#                 (restrict_value_impl): FloatRestrictValue()
#               )
#               (restrict_scaling_pre): Identity()
#             )
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#       (bias_quant): BiasQuantProxyFromInjector(
#         (_zero_hw_sentinel): StatelessBuffer()
#       )
#     )
#     (sm): Softmax(dim=1)
#   )
#   (prediction): QuantLinear(
#     in_features=40, out_features=12, bias=True
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (output_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (weight_quant): WeightQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (tensor_quant): RescalingIntQuant(
#         (int_quant): IntQuant(
#           (float_to_int_impl): RoundSte()
#           (tensor_clamp_impl): TensorClampSte()
#           (delay_wrapper): DelayWrapper(
#             (delay_impl): _NoDelay()
#           )
#         )
#         (scaling_impl): StatsFromParameterScaling(
#           (parameter_list_stats): _ParameterListStats(
#             (first_tracked_param): _ViewParameterWrapper(
#               (view_shape_impl): OverTensorView()
#             )
#             (stats): _Stats(
#               (stats_impl): AbsMax()
#             )
#           )
#           (stats_scaling_impl): _StatsScaling(
#             (affine_rescaling): Identity()
#             (restrict_clamp_scaling): _RestrictClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (restrict_scaling_pre): Identity()
#           )
#         )
#         (int_scaling_impl): IntScaling()
#         (zero_point_impl): ZeroZeroPoint(
#           (zero_point): StatelessBuffer()
#         )
#         (msb_clamp_bit_width_impl): BitWidthConst(
#           (bit_width): StatelessBuffer()
#         )
#       )
#     )
#     (bias_quant): BiasQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#   )
# )

# %%
import torch
import brevitas.onnx as bo
from brevitas.quant_tensor import QuantTensor

ready_model_filename = "pamp2_attn_conv_3.onnx"

# Export to ONNX
#Move to CPU before export
model.cpu()
inp = torch.randn(1, 1, windowsize, num_channels)
bo.export_finn_onnx(model, inp, ready_model_filename)

print("Model saved to %s" % ready_model_filename)

# %% [markdown]
# # 实验

# %%
# 如果我们设置为 


args.model_type              = "tinyhar"#"deepconvlstm"#"sahar" #"deepconvlstm"

args.cross_channel_interaction_type = "attn"
args.cross_channel_aggregation_type = "FC"
args.temporal_info_interaction_type = "lstm"
args.temporal_info_aggregation_type = "tnaive"

exp = Exp(args)

# %%
exp.model

# %%
exp.train()

# %%
dataset = data_dict[args.data_name](args)

# %%
import numpy as np

# %%
start_index = dataset.train_slidingwindows[0][1]
end_index   = dataset.train_slidingwindows[0][2]
sample_x_1    = dataset.data_x.iloc[start_index:end_index, 1:-1].values

start_index = dataset.train_slidingwindows[100][1]
end_index   = dataset.train_slidingwindows[100][2]
sample_x_2    = dataset.data_x.iloc[start_index:end_index, 1:-1].values

temp_1 = np.expand_dims(sample_x_1,0)
temp_2 = np.expand_dims(sample_x_2,0)
combined_x = np.concatenate([temp_1,temp_2],axis=0)
combined_x = np.expand_dims(combined_x,1)
combined_x = torch.tensor(combined_x).double().to(exp.device)
print(combined_x.shape)

# %%
out = exp.model(combined_x)
out = out.cpu().detach().numpy()

# %%
out.shape

# %%
weight = exp.model.wave_conv.wavelet_conv.weight.cpu().detach().numpy()

# %%
for n,p in exp.model.named_parameters():
    print(n)

# %%
import matplotlib.pyplot as plt
index1 = 0
index2 = 0

plt.figure()
plt.plot(out[0,0,:,index2])
plt.plot(out[0,1,:,index2])
plt.plot(out[0,2,:,index2])
plt.plot(out[0,3,:,index2])

# %%
# 如果我们设置为 
# args.wavelet_filtering_learnable      = True
# exp = Exp(args)
